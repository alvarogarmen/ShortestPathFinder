# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load files

# Dijkstra 

Dijkstra_Times = np.loadtxt('experimentsDone/dijkstraTimes_eur_1000')
Dijkstra_Spaces = np.loadtxt('experimentsDone/dijkstraSearchSpace_eur_1000')
Dijkstra_Rank = np.loadtxt('experimentsDone/dijkstraRanks_eur_1000')

# Bidirectional Dijkstra

Dijkstra_Bidi_Times = np.loadtxt('experimentsDone/dijkstraBidiTimes_eur_1000')
Dijkstra_Bidi_Spaces = np.loadtxt('experimentsDone/dijkstraBidiSearchSpace_eur_1000')

# A*

AStar_Times = np.loadtxt('experimentsDone/aStarTimes_eur_1000')
AStar_Spaces = np.loadtxt('experimentsDone/aStarSearchSpace_eur_1000')

# A* Bidirectional

AStar_Bidi_Times = np.loadtxt('experimentsDone/aStarBidiTimes_eur_1000')
AStar_Bidi_Spaces = np.loadtxt('experimentsDone/aStarBidiSearchSpace_eur_1000')

AStar_Bidi_Stop_Times = np.loadtxt('experimentsDone/aStarBidiStopTimes_eur_1000')
AStar_Bidi_Stop_Spaces = np.loadtxt('experimentsDone/aStarBidiStopSearchSpace_eur_1000')

# ALT

num_landmarks_values = [2**i for i in range(1, 7)]  # Change the range according to your needs
print(num_landmarks_values)
# Loop through numLandmarks values and load files into arrays
for num_landmarks in num_landmarks_values:
    if num_landmarks % 2 == 0:
        filename = f"experimentsDone/ALTFarthestSearchSpace_eur_1000_numLandmarks_{num_landmarks}"
        array_name = f"ALT_Spaces_{num_landmarks}"
        array_data = np.loadtxt(filename)
        globals()[array_name] = array_data
    filename = f"experimentsDone/ALTFarthestTimes_eur_1000_numLandmarks_{num_landmarks}"
    array_name = f"ALT_Times_{num_landmarks}"
    array_data = np.loadtxt(filename)
    globals()[array_name] = array_data
    
    filename = f"experimentsDone/ALTBidiFarthestTimes_eur_1000_numLandmarks_{num_landmarks}"
    array_name = f"ALT_Bidi_Times_{num_landmarks}"
    array_data = np.loadtxt(filename)
    globals()[array_name] = array_data
    
    filename = f"experimentsDone/ALTBidiFarthestSearchSpace_eur_1000_numLandmarks_{num_landmarks}"
    array_name = f"ALT_Bidi_Spaces_{num_landmarks}"
    array_data = np.loadtxt(filename)
    globals()[array_name] = array_data
    
    filename = f"experimentsDone/ALTBidiStopFarthestSearchSpace_eur_1000_numLandmarks_{num_landmarks}"
    array_name = f"ALT_Bidi_Stop_Spaces_{num_landmarks}"
    array_data = np.loadtxt(filename)
    globals()[array_name] = array_data
    
    filename = f"experimentsDone/ALTBidiStopFarthestTimes_eur_1000_numLandmarks_{num_landmarks}"
    array_name = f"ALT_Bidi_Stop_Times_{num_landmarks}"
    array_data = np.loadtxt(filename)
    globals()[array_name] = array_data
# Out:
# [2, 4, 8, 16, 32, 64]

# %%
print(AStar_Bidi_Stop_Times)
# Out:
# [0.442291  0.307527  0.143591  0.383862  0.90872   0.44288   1.8052
#  0.75475   1.77051   0.514453  0.2244    0.753891  0.632687  0.567293
#  0.0626484 0.90625   0.555314  0.194626  0.794822  0.105821  0.475326
#  0.723129  1.20069   0.384557  0.961153  0.263959  0.102782  0.42388
#  0.540577  0.423478  0.28292   0.107994  0.239528  0.856726  0.474925
#  0.828817  0.0910178 0.920309  0.544331  1.30454   1.58165   0.324539
#  1.47131   0.388388  0.072552  0.311093  1.67911   0.248803  0.25482
#  0.670573  1.31861   0.283124  0.135823  0.186244  0.142914  0.398921
#  0.337372  1.62628   0.072695  0.463714  0.0730088 0.0711754 0.142828
#  0.086931  0.354503  1.55714   0.139191  0.828428  1.07197   0.105862
#  0.933933  0.255416  0.282221  0.119818  0.701189  0.100565  0.089299
#  0.392046  0.204883  0.0860883 0.187121  0.127652  0.398937  0.132249
#  0.480861  0.166541  0.105534  0.401303  0.912941  1.2888    0.266213
# ...

# %%
import numpy as np

# Function to calculate average and error margin of a given set of data
def calculate_average_with_error(data):
    avg = np.mean(data)
    error = np.std(data) / np.sqrt(len(data))
    return avg, error

# Function to split the data into groups of 5 elements
def split_into_groups(data, group_size=5):
    return [data[i:i+group_size] for i in range(0, len(data), group_size)]

# Load your data (you've already loaded the data, so no need to repeat it here)

# Define the group size
group_size = 5

# Split each array into groups of 5 elements
Dijkstra_Times_groups = split_into_groups(Dijkstra_Times, group_size)
Dijkstra_Spaces_groups = split_into_groups(Dijkstra_Spaces, group_size)
Dijkstra_Rank_groups = split_into_groups(Dijkstra_Rank, group_size)

Dijkstra_Bidi_Times_groups = split_into_groups(Dijkstra_Bidi_Times, group_size)
Dijkstra_Bidi_Spaces_groups = split_into_groups(Dijkstra_Bidi_Spaces, group_size)

AStar_Times_groups = split_into_groups(AStar_Times, group_size)
AStar_Spaces_groups = split_into_groups(AStar_Spaces, group_size)

AStar_Bidi_Times_groups = split_into_groups(AStar_Bidi_Times, group_size)
AStar_Bidi_Spaces_groups = split_into_groups(AStar_Bidi_Spaces, group_size)

# Split each ALT array into groups of 5 elements
ALT_Times_groups = split_into_groups(ALT_Times_16, group_size)
ALT_Spaces_groups = split_into_groups(ALT_Spaces_16, group_size)
ALT_Bidi_Times_groups = split_into_groups(ALT_Bidi_Stop_Times_16, group_size)
ALT_Bidi_Spaces_groups = split_into_groups(ALT_Bidi_Spaces_16, group_size)

# ALT arrays have already been loaded into arrays named as per the loop

# Function to calculate averages and error margins for each group in the data
def calculate_averages_with_error_for_groups(data_groups):
    averages = []
    errors = []
    for group in data_groups:
        avg, error = calculate_average_with_error(group)
        averages.append(avg)
        errors.append(error)
    return averages, errors

# Calculate averages and error margins for each group in the data
Dijkstra_Times_avg, Dijkstra_Times_error = calculate_averages_with_error_for_groups(Dijkstra_Times_groups)
Dijkstra_Spaces_avg, Dijkstra_Spaces_error = calculate_averages_with_error_for_groups(Dijkstra_Spaces_groups)
Dijkstra_Rank_avg, Dijkstra_Rank_error = calculate_averages_with_error_for_groups(Dijkstra_Rank_groups)

Dijkstra_Bidi_Times_avg, Dijkstra_Bidi_Times_error = calculate_averages_with_error_for_groups(Dijkstra_Bidi_Times_groups)
Dijkstra_Bidi_Spaces_avg, Dijkstra_Bidi_Spaces_error = calculate_averages_with_error_for_groups(Dijkstra_Bidi_Spaces_groups)

AStar_Times_avg, AStar_Times_error = calculate_averages_with_error_for_groups(AStar_Times_groups)
AStar_Spaces_avg, AStar_Spaces_error = calculate_averages_with_error_for_groups(AStar_Spaces_groups)

AStar_Bidi_Times_avg, AStar_Bidi_Times_error = calculate_averages_with_error_for_groups(AStar_Bidi_Times_groups)
AStar_Bidi_Spaces_avg, AStar_Bidi_Spaces_error = calculate_averages_with_error_for_groups(AStar_Bidi_Spaces_groups)

# Calculate averages and error margins for each group in the ALT data
ALT_Times_avg, ALT_Times_error = calculate_averages_with_error_for_groups(ALT_Times_groups)
#ALT_Spaces_avg, ALT_Spaces_error = calculate_averages_with_error_for_groups(ALT_Spaces_groups)
ALT_Bidi_Times_avg, ALT_Bidi_Times_error = calculate_averages_with_error_for_groups(ALT_Bidi_Times_groups)
#ALT_Bidi_Spaces_avg, ALT_Bidi_Spaces_error = calculate_averages_with_error_for_groups(ALT_Bidi_Spaces_groups)

# %%
plt.scatter(Dijkstra_Rank_avg, Dijkstra_Times_avg, color='b')
plt.scatter(Dijkstra_Rank_avg, Dijkstra_Bidi_Times_avg, color='r')
plt.scatter(Dijkstra_Rank_avg, AStar_Times_avg, color='black')
plt.scatter(Dijkstra_Rank_avg, AStar_Bidi_Times_avg, color='grey')
plt.scatter(Dijkstra_Rank_avg, ALT_Times_avg, color='purple')
plt.scatter(Dijkstra_Rank_avg, ALT_Bidi_Times_avg, color='pink')
plt.yscale('log')
plt.show()
print(np.sort(Dijkstra_Rank_avg))
print(np.sort(Dijkstra_Rank))
# Out:
# [1320.6 1407.2 1409.8 1430.8 1458.8 1485.8 1600.2 1669.  1727.6 1770.6
#  1773.2 1801.6 1826.4 1845.2 1919.8 1940.8 2004.6 2010.2 2011.2 2020.4
#  2049.4 2050.8 2052.8 2061.6 2109.6 2126.8 2155.8 2175.6 2181.4 2219.6
#  2232.2 2243.4 2248.4 2248.6 2363.  2368.6 2385.2 2428.6 2428.8 2431.6
#  2435.2 2437.4 2453.2 2461.8 2462.2 2479.4 2481.2 2486.6 2494.  2518.6
#  2520.  2550.6 2557.  2570.8 2592.6 2594.4 2599.8 2601.6 2606.  2613.8
#  2645.6 2662.4 2677.6 2685.6 2688.4 2691.2 2705.  2706.6 2721.  2743.
#  2748.8 2750.  2762.4 2779.2 2780.4 2807.2 2811.4 2816.8 2820.8 2828.4
#  2839.4 2852.8 2853.6 2884.4 2886.6 2886.8 2891.2 2894.  2899.4 2902.4
#  2917.  2923.4 2936.2 2951.6 2959.4 2984.  2986.8 2987.4 2988.  2993.4
#  3003.2 3006.6 3031.4 3040.6 3042.2 3042.4 3063.4 3071.6 3078.6 3101.8
#  3109.  3122.4 3125.6 3126.4 3143.  3169.4 3192.  3206.  3220.2 3220.6
#  3236.2 3263.6 3298.2 3300.  3327.8 3334.6 3337.2 3362.  3386.4 3392.6
# ...

# %%
x_values = np.sort(Dijkstra_Rank_avg)  # Replace with the correct x-axis values (1 to 10 for 10 groups)

# Assuming Dijkstra_Times_avg and Dijkstra_Times_error are lists, convert them to numpy arrays
y_values = np.array(Dijkstra_Times_avg)  # Replace with the correct average values
y_errors = np.array(Dijkstra_Times_error)  # Replace with the correct error margin values

# Sort y_values and y_errors based on x_values
sorted_indices = np.argsort(x_values)
y_values_sorted = y_values[sorted_indices]
y_errors_sorted = y_errors[sorted_indices]

# Plot the scatter plot with error bars and connecting lines
plt.errorbar(x_values, y_values_sorted, yerr=y_errors_sorted, marker='o', linestyle='-', capsize=4)
plt.plot(x_values, y_values_sorted, linestyle='-', marker='o')  # Add connecting lines

# Add labels and title
plt.xlabel('Group Number')
plt.ylabel('Average Time')
plt.title('Average Time with Error Bars for Dijkstra Times')

# Show the plot
plt.show()

# %%
plt.scatter(Dijkstra_Spaces, Dijkstra_Times*1000, color='blue', label='Dijkstra', s=10)
plt.scatter(Dijkstra_Spaces, AStar_Times*1000, color='green', label='A*', s=10)
plt.scatter(Dijkstra_Spaces, AStar_Bidi_Times*1000, color='yellow', label='BA*', s=10)
plt.scatter(Dijkstra_Spaces, AStar_Bidi_Stop_Times*1000, color='magenta', label='BA**', s=10)
plt.scatter(Dijkstra_Spaces, ALT_Times_64*1000, color='black', label='ALT-16', s=10)
plt.scatter(Dijkstra_Spaces, ALT_Bidi_Times_64*1000, color='purple', label='BALT-16', s=10)
plt.scatter(Dijkstra_Spaces, ALT_Bidi_Stop_Times_64*1000, color='pink', label='BALT*-16', s=10)
plt.ylabel('Query time [ms]')
plt.xlabel('Dijkstra Rank')
plt.yscale('log')
plt.xscale('log', base=2)
plt.xlim(2**15, 2**26)
plt.xticks(2**np.arange(15, 26))
plt.legend(loc='upper left')
plt.show()

# %%
def get_indices(a, b):
  """
  Gets the indices in `a` for which `a[i]` is bigger than 2^12.

  Args:
    a: The array of ranks.
    b: The array of measurements.

  Returns:
    A list of the indices in `a` for which `a[i]` is bigger than 2^12.
  """

  indices = []
  for i in range(len(a)):
    if a[i] > 2**1:
      indices.append(i)

  return indices

def get_array(a, indices):
  """
  Gets an array where only the entries in `indices` are present.

  Args:
    a: The original array.
    indices: The list of indices of the entries that should be present in the new array.

  Returns:
    The new array.
  """

  new_array = []
  for i in indices:
    new_array.append(a[i])

  return np.array(new_array)

# %%
Select_Dijkstra = get_array(Dijkstra_Times, get_indices(Dijkstra_Spaces, Dijkstra_Times))
Select_Bidi_Dijkstra = get_array(Dijkstra_Bidi_Times, get_indices(Dijkstra_Spaces, Dijkstra_Bidi_Times))
Select_AStar = get_array(AStar_Times, get_indices(Dijkstra_Spaces, AStar_Times))
Select_AStar_Bidi = get_array(AStar_Bidi_Times, get_indices(Dijkstra_Spaces, AStar_Bidi_Times))
Select_AStar_Bidi_Stop = get_array(AStar_Bidi_Stop_Times, get_indices(Dijkstra_Spaces, AStar_Bidi_Stop_Times))
Select_ALT_64 = get_array(ALT_Times_64, get_indices(Dijkstra_Spaces, ALT_Times_64))
Select_ALT_Bidi_64 = get_array(ALT_Bidi_Times_64, get_indices(Dijkstra_Spaces, ALT_Bidi_Times_64))
Select_ALT_Bidi_Stop_64 = get_array(ALT_Bidi_Stop_Times_64, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Times_64))
Select_ALT_32 = get_array(ALT_Times_32, get_indices(Dijkstra_Spaces, ALT_Times_32))
Select_ALT_Bidi_32 = get_array(ALT_Bidi_Times_32, get_indices(Dijkstra_Spaces, ALT_Bidi_Times_32))
Select_ALT_Bidi_Stop_32 = get_array(ALT_Bidi_Stop_Times_32, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Times_32))
Select_ALT_16 = get_array(ALT_Times_16, get_indices(Dijkstra_Spaces, ALT_Times_16))
Select_ALT_Bidi_16 = get_array(ALT_Bidi_Times_16, get_indices(Dijkstra_Spaces, ALT_Bidi_Times_16))
Select_ALT_Bidi_Stop_16 = get_array(ALT_Bidi_Stop_Times_16, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Times_16))
Select_ALT_8 = get_array(ALT_Times_8, get_indices(Dijkstra_Spaces, ALT_Times_8))
Select_ALT_Bidi_8 = get_array(ALT_Bidi_Times_8, get_indices(Dijkstra_Spaces, ALT_Bidi_Times_8))
Select_ALT_Bidi_Stop_8 = get_array(ALT_Bidi_Stop_Times_8, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Times_8))
Select_ALT_4 = get_array(ALT_Times_4, get_indices(Dijkstra_Spaces, ALT_Times_4))
Select_ALT_Bidi_4 = get_array(ALT_Bidi_Times_4, get_indices(Dijkstra_Spaces, ALT_Bidi_Times_4))
Select_ALT_Bidi_Stop_4 = get_array(ALT_Bidi_Stop_Times_4, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Times_4))
Select_ALT_2 = get_array(ALT_Times_2, get_indices(Dijkstra_Spaces, ALT_Times_2))
Select_ALT_Bidi_2 = get_array(ALT_Bidi_Times_2, get_indices(Dijkstra_Spaces, ALT_Bidi_Times_2))
Select_ALT_Bidi_Stop_2 = get_array(ALT_Bidi_Stop_Times_2, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Times_2))

# %%
print(np.mean(Select_ALT_16))
print(np.mean(Select_Dijkstra))

print('BD: ',np.round(np.mean(Select_Dijkstra/Select_Bidi_Dijkstra), 1))
print('A*: ',np.round(np.mean(Select_Dijkstra/Select_AStar), 1))
print('BA*: ', np.round(np.mean(Select_Dijkstra/Select_AStar_Bidi), 1))
print('BA**: ', np.round(np.mean(Select_Dijkstra/Select_AStar_Bidi_Stop), 1))
print('ALT 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_2), 1))
print('BALT 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_2), 1))
print('BALT* 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_2), 1))
print('ALT 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_4), 1))
print('BALT 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_4), 1))
print('BALT* 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_4), 1))
print('ALT 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_8), 1))
print('BALT 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_8), 1))
print('BALT* 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_8), 1))
print('ALT 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_16), 1))
print('BALT 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_16), 1))
print('BALT* 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_16), 1))
print('ALT 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_32), 1))
print('BALT 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_32), 1))
print('BALT* 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_32), 1))
print('ALT 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_64), 1))
print('BALT 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_64), 1))
print('BALT* 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_64), 1))
# Out:
# 0.47143003206412826
# 2.730215997695391
# BD:  1.6
# A*:  3.1
# BA*:  3.3
# BA**:  6.8
# ALT 2:  3.6
# BALT 2:  5.5
# BALT* 2:  7.5
# ALT 4:  4.1
# BALT 4:  6.6
# BALT* 4:  9.1
# ALT 8:  5.5
# BALT 8:  10.2
# BALT* 8:  12.8
# ALT 16:  6.1
# BALT 16:  11.5
# BALT* 16:  13.7
# ALT 32:  5.9
# BALT 32:  11.2
# BALT* 32:  12.6
# ALT 64:  5.7
# BALT 64:  11.1
# BALT* 64:  12.1

# %%
plt.scatter(Dijkstra_Rank, Dijkstra_Times*1000, color='blue', label='Dijkstra', s=10)
plt.scatter(Dijkstra_Rank, AStar_Times*1000, color='green', label='A*', s=10)
plt.scatter(Dijkstra_Rank, AStar_Bidi_Times*1000, color='yellow', label='BA*', s=10)
plt.scatter(Dijkstra_Rank, AStar_Bidi_Stop_Times*1000, color='magenta', label='BA**', s=10)
plt.scatter(Dijkstra_Rank, ALT_Times_64*1000, color='black', label='ALT-16', s=10)
plt.scatter(Dijkstra_Rank, ALT_Bidi_Times_64*1000, color='purple', label='BALT-16', s=10)
plt.scatter(Dijkstra_Rank, ALT_Bidi_Stop_Times_64*1000, color='pink', label='BALT*-16', s=10)
plt.ylabel('Query time [ms]')
plt.yscale('log')
plt.xscale('log', base=2)
plt.xticks(2**np.arange(6, 15))
plt.legend(loc='upper left')
plt.show()

# %%
Select_Dijkstra = get_array(Dijkstra_Times, get_indices(Dijkstra_Rank, Dijkstra_Times))
Select_Bidi_Dijkstra = get_array(Dijkstra_Bidi_Times, get_indices(Dijkstra_Rank, Dijkstra_Bidi_Times))
Select_AStar = get_array(AStar_Times, get_indices(Dijkstra_Rank, AStar_Times))
Select_AStar_Bidi = get_array(AStar_Bidi_Times, get_indices(Dijkstra_Rank, AStar_Bidi_Times))
Select_AStar_Bidi_Stop = get_array(AStar_Bidi_Stop_Times, get_indices(Dijkstra_Rank, AStar_Bidi_Stop_Times))
Select_ALT_64 = get_array(ALT_Times_64, get_indices(Dijkstra_Rank, ALT_Times_64))
Select_ALT_Bidi_64 = get_array(ALT_Bidi_Times_64, get_indices(Dijkstra_Rank, ALT_Bidi_Times_64))
Select_ALT_Bidi_Stop_64 = get_array(ALT_Bidi_Stop_Times_64, get_indices(Dijkstra_Rank, ALT_Bidi_Stop_Times_64))
Select_ALT_32 = get_array(ALT_Times_32, get_indices(Dijkstra_Rank, ALT_Times_32))
Select_ALT_Bidi_32 = get_array(ALT_Bidi_Times_32, get_indices(Dijkstra_Rank, ALT_Bidi_Times_32))
Select_ALT_Bidi_Stop_32 = get_array(ALT_Bidi_Stop_Times_32, get_indices(Dijkstra_Rank, ALT_Bidi_Stop_Times_32))
Select_ALT_16 = get_array(ALT_Times_16, get_indices(Dijkstra_Rank, ALT_Times_16))
Select_ALT_Bidi_16 = get_array(ALT_Bidi_Times_16, get_indices(Dijkstra_Rank, ALT_Bidi_Times_16))
Select_ALT_Bidi_Stop_16 = get_array(ALT_Bidi_Stop_Times_16, get_indices(Dijkstra_Rank, ALT_Bidi_Stop_Times_16))
Select_ALT_8 = get_array(ALT_Times_8, get_indices(Dijkstra_Rank, ALT_Times_8))
Select_ALT_Bidi_8 = get_array(ALT_Bidi_Times_8, get_indices(Dijkstra_Rank, ALT_Bidi_Times_8))
Select_ALT_Bidi_Stop_8 = get_array(ALT_Bidi_Stop_Times_8, get_indices(Dijkstra_Rank, ALT_Bidi_Stop_Times_8))
Select_ALT_4 = get_array(ALT_Times_4, get_indices(Dijkstra_Rank, ALT_Times_4))
Select_ALT_Bidi_4 = get_array(ALT_Bidi_Times_4, get_indices(Dijkstra_Rank, ALT_Bidi_Times_4))
Select_ALT_Bidi_Stop_4 = get_array(ALT_Bidi_Stop_Times_4, get_indices(Dijkstra_Rank, ALT_Bidi_Stop_Times_4))
Select_ALT_2 = get_array(ALT_Times_2, get_indices(Dijkstra_Rank, ALT_Times_2))
Select_ALT_Bidi_2 = get_array(ALT_Bidi_Times_2, get_indices(Dijkstra_Rank, ALT_Bidi_Times_2))
Select_ALT_Bidi_Stop_2 = get_array(ALT_Bidi_Stop_Times_2, get_indices(Dijkstra_Rank, ALT_Bidi_Stop_Times_2))

# %%
print('D: ', np.round(np.mean(Select_Dijkstra), 1))
print('BD: ',np.round(np.mean( Select_Bidi_Dijkstra), 1))
print('A*: ',np.round(np.mean( Select_AStar), 1))
print('BA*: ', np.round(np.mean( Select_AStar_Bidi), 1))
print('BA**: ', np.round(np.mean( Select_AStar_Bidi_Stop), 1))
print('ALT 2: ', np.round(np.mean( Select_ALT_2), 1))
print('BALT 2: ', np.round(np.mean( Select_ALT_Bidi_2), 1))
print('BALT* 2: ', np.round(np.mean( Select_ALT_Bidi_Stop_2), 1))
print('ALT 4: ', np.round(np.mean( Select_ALT_4), 1))
print('BALT 4: ', np.round(np.mean( Select_ALT_Bidi_4), 1))
print('BALT* 4: ', np.round(np.mean( Select_ALT_Bidi_Stop_4), 1))
print('ALT 8: ', np.round(np.mean( Select_ALT_8), 1))
print('BALT 8: ', np.round(np.mean( Select_ALT_Bidi_8), 1))
print('BALT* 8: ', np.round(np.mean( Select_ALT_Bidi_Stop_8), 1))
print('ALT 16: ', np.round(np.mean( Select_ALT_16), 1))
print('BALT 16: ', np.round(np.mean( Select_ALT_Bidi_16), 1))
print('BALT* 16: ', np.round(np.mean( Select_ALT_Bidi_Stop_16), 1))
print('ALT 32: ', np.round(np.mean( Select_ALT_32), 1))
print('BALT 32: ', np.round(np.mean( Select_ALT_Bidi_32), 1))
print('BALT* 32: ', np.round(np.mean( Select_ALT_Bidi_Stop_32), 1))
print('ALT 64: ', np.round(np.mean( Select_ALT_64), 1))
print('BALT 64: ', np.round(np.mean( Select_ALT_Bidi_64), 1))
print('BALT* 64: ', np.round(np.mean( Select_ALT_Bidi_Stop_64), 1))
# Out:
# D:  2.7
# BD:  1.8
# A*:  1.0
# BA*:  1.3
# BA**:  0.5
# ALT 2:  0.9
# BALT 2:  1.1
# BALT* 2:  0.7
# ALT 4:  0.8
# BALT 4:  0.9
# BALT* 4:  0.6
# ALT 8:  0.6
# BALT 8:  0.5
# BALT* 8:  0.3
# ALT 16:  0.5
# BALT 16:  0.4
# BALT* 16:  0.3
# ALT 32:  0.5
# BALT 32:  0.4
# BALT* 32:  0.3
# ALT 64:  0.5
# BALT 64:  0.4
# BALT* 64:  0.3

# %%
print('BD: ',np.round(np.mean(Select_Dijkstra/Select_Bidi_Dijkstra), 1))
print('A*: ',np.round(np.mean(Select_Dijkstra/Select_AStar), 1))
print('BA*: ', np.round(np.mean(Select_Dijkstra/Select_AStar_Bidi), 1))
print('BA**: ', np.round(np.mean(Select_Dijkstra/Select_AStar_Bidi_Stop), 1))
print('ALT 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_2), 1))
print('BALT 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_2), 1))
print('BALT* 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_2), 1))
print('ALT 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_4), 1))
print('BALT 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_4), 1))
print('BALT* 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_4), 1))
print('ALT 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_8), 1))
print('BALT 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_8), 1))
print('BALT* 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_8), 1))
print('ALT 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_16), 1))
print('BALT 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_16), 1))
print('BALT* 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_16), 1))
print('ALT 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_32), 1))
print('BALT 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_32), 1))
print('BALT* 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_32), 1))
print('ALT 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_64), 1))
print('BALT 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_64), 1))
print('BALT* 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_64), 1))
# Out:
# BD:  1.6
# A*:  3.1
# BA*:  3.3
# BA**:  6.8
# ALT 2:  3.6
# BALT 2:  5.5
# BALT* 2:  7.5
# ALT 4:  4.1
# BALT 4:  6.6
# BALT* 4:  9.1
# ALT 8:  5.5
# BALT 8:  10.2
# BALT* 8:  12.8
# ALT 16:  6.1
# BALT 16:  11.5
# BALT* 16:  13.7
# ALT 32:  5.9
# BALT 32:  11.2
# BALT* 32:  12.6
# ALT 64:  5.7
# BALT 64:  11.1
# BALT* 64:  12.1

# %%
print('A*: ',np.round(np.mean(Dijkstra_Times/AStar_Times), 1))
print('BA*: ', np.round(np.mean(Dijkstra_Times/AStar_Bidi_Times), 1))
print('BA**: ', np.round(np.mean(Dijkstra_Times/AStar_Bidi_Stop_Times), 1))
print('ALT: ', np.round(np.mean(Dijkstra_Times/ALT_Times_16), 1))
print('BALT: ', np.round(np.mean(Dijkstra_Times/ALT_Bidi_Times_16), 1))
print('BALT*: ', np.round(np.mean(Dijkstra_Times/ALT_Bidi_Stop_Times_16), 1))
# Out:
# A*:  3.1
# BA*:  3.3
# BA**:  6.8
# ALT:  6.0
# BALT:  11.4
# BALT*:  13.7

# %%
plt.scatter(Dijkstra_Spaces, Dijkstra_Spaces, color='blue', label='Dijkstra', s=10)
plt.scatter(Dijkstra_Spaces, AStar_Spaces, color='green', label='A*', s=10)
plt.scatter(Dijkstra_Spaces, AStar_Bidi_Spaces, color='yellow', label='BA*', s=10)
plt.scatter(Dijkstra_Spaces, AStar_Bidi_Stop_Spaces, color='magenta', label='BA**', s=10)
plt.scatter(Dijkstra_Spaces, ALT_Spaces_64, color='black', label='ALT-16', s=10)
plt.scatter(Dijkstra_Spaces, ALT_Bidi_Spaces_64, color='purple', label='BALT-16', s=10)
plt.scatter(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_64, color='pink', label='BALT*-16', s=10)
plt.ylabel('Search Space [Setled Nodes]')
plt.xlabel('Dijkstra Rank')
plt.yscale('log')
plt.ylim(10**3, 10**8)
plt.xscale('log', base=2)
plt.xlim(2**15, 2**26)
plt.xticks(2**np.arange(15, 26))
plt.legend(loc='upper left')
plt.show()

# %%
Select_Dijkstra = get_array(Dijkstra_Spaces, get_indices(Dijkstra_Spaces, Dijkstra_Spaces))
Select_Bidi_Dijkstra = get_array(Dijkstra_Bidi_Spaces, get_indices(Dijkstra_Spaces, Dijkstra_Bidi_Spaces))
Select_AStar = get_array(AStar_Spaces, get_indices(Dijkstra_Spaces, AStar_Spaces))
Select_AStar_Bidi = get_array(AStar_Bidi_Spaces, get_indices(Dijkstra_Spaces, AStar_Bidi_Spaces))
Select_AStar_Bidi_Stop = get_array(AStar_Bidi_Stop_Spaces, get_indices(Dijkstra_Spaces, AStar_Bidi_Stop_Spaces))
Select_ALT_64 = get_array(ALT_Spaces_64, get_indices(Dijkstra_Spaces, ALT_Spaces_64))
Select_ALT_Bidi_64 = get_array(ALT_Bidi_Spaces_64, get_indices(Dijkstra_Spaces, ALT_Bidi_Spaces_64))
Select_ALT_Bidi_Stop_64 = get_array(ALT_Bidi_Stop_Spaces_64, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_64))
Select_ALT_32 = get_array(ALT_Spaces_32, get_indices(Dijkstra_Spaces, ALT_Spaces_32))
Select_ALT_Bidi_32 = get_array(ALT_Bidi_Spaces_32, get_indices(Dijkstra_Spaces, ALT_Bidi_Spaces_32))
Select_ALT_Bidi_Stop_32 = get_array(ALT_Bidi_Stop_Spaces_32, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_32))
Select_ALT_16 = get_array(ALT_Spaces_16, get_indices(Dijkstra_Spaces, ALT_Spaces_16))
Select_ALT_Bidi_16 = get_array(ALT_Bidi_Spaces_16, get_indices(Dijkstra_Spaces, ALT_Bidi_Spaces_16))
Select_ALT_Bidi_Stop_16 = get_array(ALT_Bidi_Stop_Spaces_16, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_16))
Select_ALT_8 = get_array(ALT_Spaces_8, get_indices(Dijkstra_Spaces, ALT_Spaces_8))
Select_ALT_Bidi_8 = get_array(ALT_Bidi_Spaces_8, get_indices(Dijkstra_Spaces, ALT_Bidi_Spaces_8))
Select_ALT_Bidi_Stop_8 = get_array(ALT_Bidi_Stop_Spaces_8, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_8))
Select_ALT_4 = get_array(ALT_Spaces_4, get_indices(Dijkstra_Spaces, ALT_Spaces_4))
Select_ALT_Bidi_4 = get_array(ALT_Bidi_Spaces_4, get_indices(Dijkstra_Spaces, ALT_Bidi_Spaces_4))
Select_ALT_Bidi_Stop_4 = get_array(ALT_Bidi_Stop_Spaces_4, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_4))
Select_ALT_2 = get_array(ALT_Spaces_2, get_indices(Dijkstra_Spaces, ALT_Spaces_2))
Select_ALT_Bidi_2 = get_array(ALT_Bidi_Spaces_2, get_indices(Dijkstra_Spaces, ALT_Bidi_Spaces_2))
Select_ALT_Bidi_Stop_2 = get_array(ALT_Bidi_Stop_Spaces_2, get_indices(Dijkstra_Spaces, ALT_Bidi_Stop_Spaces_2))

# %%
print('D: ', np.round(np.mean(Select_Dijkstra), 1))
print('BD: ',np.round(np.mean(Select_Bidi_Dijkstra), 1))
print('A*: ',np.round(np.mean(Select_AStar), 1))
print('BA*: ', np.round(np.mean(Select_AStar_Bidi), 1))
print('BA**: ', np.round(np.mean(Select_AStar_Bidi_Stop), 1))
print('ALT 2: ', np.round(np.mean(Select_ALT_2), 1))
print('BALT 2: ', np.round(np.mean(Select_ALT_Bidi_2), 1))
print('BALT* 2: ', np.round(np.mean( Select_ALT_Bidi_Stop_2), 1))
print('ALT 4: ', np.round(np.mean( Select_ALT_4), 1))
print('BALT 4: ', np.round(np.mean( Select_ALT_Bidi_4), 1))
print('BALT* 4: ', np.round(np.mean( Select_ALT_Bidi_Stop_4), 1))
print('ALT 8: ', np.round(np.mean( Select_ALT_8), 1))
print('BALT 8: ', np.round(np.mean( Select_ALT_Bidi_8), 1))
print('BALT* 8: ', np.round(np.mean( Select_ALT_Bidi_Stop_8), 1))
print('ALT 16: ', np.round(np.mean( Select_ALT_16), 1))
print('BALT 16: ', np.round(np.mean( Select_ALT_Bidi_16), 1))
print('BALT* 16: ', np.round(np.mean( Select_ALT_Bidi_Stop_16), 1))
print('ALT 32: ', np.round(np.mean( Select_ALT_32), 1))
print('BALT 32: ', np.round(np.mean( Select_ALT_Bidi_32), 1))
print('BALT* 32: ', np.round(np.mean( Select_ALT_Bidi_Stop_32), 1))
print('ALT 64: ', np.round(np.mean( Select_ALT_64), 1))
print('BALT 64: ', np.round(np.mean( Select_ALT_Bidi_64), 1))
print('BALT* 64: ', np.round(np.mean( Select_ALT_Bidi_Stop_64), 1))
print(22222294/556672)
print(9114385/604968)
# Out:
# D:  22222294.0
# BD:  14181499.7
# A*:  6150998.7
# BA*:  9119014.7
# BA**:  3314011.6
# ALT 2:  5708480.7
# BALT 2:  7329980.9
# BALT* 2:  4443773.5
# ALT 4:  4462545.2
# BALT 4:  5841343.0
# BALT* 4:  3553109.7
# ALT 8:  2246660.7
# BALT 8:  2579125.4
# BALT* 8:  1617196.5
# ALT 16:  1409745.9
# BALT 16:  1505126.3
# BALT* 16:  1017224.6
# ALT 32:  1126949.8
# BALT 32:  1165643.7
# BALT* 32:  917610.1
# ALT 64:  704697.6
# BALT 64:  657263.6
# BALT* 64:  556672.1
# 39.91990615658772
# 15.065896047394242

# %%
print('BD: ',np.round(np.mean(Select_Dijkstra/Select_Bidi_Dijkstra), 1))
print('A*: ',np.round(np.mean(Select_Dijkstra/Select_AStar), 1))
print('BA*: ', np.round(np.mean(Select_Dijkstra/Select_AStar_Bidi), 1))
print('BA**: ', np.round(np.mean(Select_Dijkstra/Select_AStar_Bidi_Stop), 1))
print('ALT 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_2), 1))
print('BALT 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_2), 1))
print('BALT* 2: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_2), 1))
print('ALT 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_4), 1))
print('BALT 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_4), 1))
print('BALT* 4: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_4), 1))
print('ALT 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_8), 1))
print('BALT 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_8), 1))
print('BALT* 8: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_8), 1))
print('ALT 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_16), 1))
print('BALT 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_16), 1))
print('BALT* 16: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_16), 1))
print('ALT 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_32), 1))
print('BALT 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_32), 1))
print('BALT* 32: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_32), 1))
print('ALT 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_64), 1))
print('BALT 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_64), 1))
print('BALT* 64: ', np.round(np.mean(Select_Dijkstra/Select_ALT_Bidi_Stop_64), 1))
# Out:
# BD:  1.7
# A*:  7.0
# BA*:  4.5
# BA**:  12.7
# ALT 2:  15.4
# BALT 2:  16.9
# BALT* 2:  31.2
# ALT 4:  18.5
# BALT 4:  19.5
# BALT* 4:  35.7
# ALT 8:  36.3
# BALT 8:  41.9
# BALT* 8:  70.4
# ALT 16:  45.0
# BALT 16:  54.4
# BALT* 16:  71.4
# ALT 32:  61.2
# BALT 32:  67.9
# BALT* 32:  80.2
# ALT 64:  81.7
# BALT 64:  115.6
# BALT* 64:  126.5
