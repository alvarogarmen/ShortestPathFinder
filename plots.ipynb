# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('roadnetworks/eur.graph.xyz', delimiter=' ', skiprows=1)
x_coord = [subarray[0] for subarray in data]
y_coord = [subarray[1] for subarray in data]
plt.scatter(x_coord, y_coord, s=0.001)
plt.axis('off')
plt.show()
